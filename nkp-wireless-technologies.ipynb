# %%
from IPython.core.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from sys import path; path.insert(1,"../src");
import fubar; from importlib import reload; reload(fubar);
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-wireless-technologies/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Topologies``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %%
# from sys import path; path.insert(1,"../src")
# from fubar import fFile

# %%
# %%script bash
# grep -1 "def fFile" ../src/fubar.py -A 9
# Out:
# # repository ./SeanOhAileasa
# def fFile(nParPath):
#     """Start a file with its associated application.
#
# Input: nParPath
# Process: (os.path.realpath; os.startfile)
# Output: file opened with associated application
# """
#     from os import path,startfile
#     return startfile(path.realpath(nParPath))
# # --- END ---

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ###### Quick Links
# ***
#
# * [Wireless Technologies](#topWirelessTechnologies)&nbsp;&nbsp;|&nbsp;&nbsp;[Test](#topWirelessTechnologiesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# <a id="topWirelessTechnologies"></a>
# ### [Wireless Technologies](#wirelessTechnologies)
#
# * [1. 802.11 Standards](#wirelessTechnologies180211Standards) <br/><br/>
#     * [802.11a](#wirelessTechnologies180211Standards80211a) <br/><br/>
#     * [802.11b](#wirelessTechnologies180211Standards80211b) <br/><br/>
#     * [802.11g](#wirelessTechnologies180211Standards80211g) <br/><br/>
#     * [802.11n](#wirelessTechnologies180211Standards80211n) <br/><br/>
#     * [802.11ac](#wirelessTechnologies180211Standards80211ac) <br/><br/>
# * [2. Cellular Technologies](#wirelessTechnologies2CellularTechnologies) <br/><br/>
#     * [GSM](#wirelessTechnologies2CellularTechnologiesGSM) <br/><br/>
#     * [Time Division Multiple Access - TDMA](#wirelessTechnologies2CellularTechnologiesTimeDivisionMultipleAccessTDMA) <br/><br/>
#     * [Code Division Multiple Access - CDMA](#wirelessTechnologies2CellularTechnologiesCodeDivisionMultipleAccessCDMA) <br/><br/>
# * [3. Frequencies](#wirelessTechnologies3Frequencies) <br/><br/>
#     * [Frequency](#wirelessTechnologies3FrequenciesFrequency) <br/><br/>
#         * [IEEE 802.11 Specification](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification) <br/><br/>
#             * [2.4 GHz](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHz) <br/><br/>
#                 * [Advantages](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHzAdvantages) <br/><br/>
#                 * [Disadvantages](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHzDisadvantages) <br/><br/>
#             * [5 GHz](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHz) <br/><br/>
#                 * [Advantages](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHzAdvantages) <br/><br/>
#                 * [Disadvantages](#wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHzDisadvantages) <br/><br/>
# * [4. Speed and Distance Requirements](#wirelessTechnologies4SpeedandDistanceRequirements) <br/><br/>
#     * [802.11a](#wirelessTechnologies4SpeedandDistanceRequirements80211a) <br/><br/>
#     * [802.11b](#wirelessTechnologies4SpeedandDistanceRequirements80211b) <br/><br/>
#     * [802.11g](#wirelessTechnologies4SpeedandDistanceRequirements80211g) <br/><br/>
#     * [802.11n](#wirelessTechnologies4SpeedandDistanceRequirements80211n) <br/><br/>
# * [5. Channel Bandwidth](#wirelessTechnologies5ChannelBandwidth) <br/><br/>
#     * [Channel Width](#wirelessTechnologies5ChannelBandwidthChannelWidth) <br/><br/>
# * [6. Channel Bonding](#wirelessTechnologies6ChannelBonding) <br/><br/>
#     * [2.4 GHz](#wirelessTechnologies6ChannelBonding24GHz) <br/><br/>
#     * [5 GHz](#wirelessTechnologies6ChannelBonding5GHz) <br/><br/>
# * [7. MIMO/MU-MIMO](#wirelessTechnologies7MIMOMUMIMO) <br/><br/>
#     * [Multiple Input Multiple Output - MIMO](#wirelessTechnologies7MIMOMUMIMOMIMO) <br/><br/>
#     * [Multi-User MIMO](#wirelessTechnologies7MIMOMUMIMOMUMIMO) <br/><br/>
# * [8. Unidirectional vs. Omnidirectional Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennas) <br/><br/>
#     * [Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasAntennas) <br/><br/>
#         * [Omnidirectional Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasOmnidirectionalAntennas) <br/><br/>
#         * [Directional Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasDirectionalAntennas) <br/><br/>
#             * [Bidirectional Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasBidirectionalAntennas) <br/><br/>
#         * [Yagi-Uda Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasYagiUdaAntennas) <br/><br/>
#         * [Parabolic Dish Antennas](#wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasParabolicDishAntennas) <br/><br/>
# * [9. Site Surveys](#wirelessTechnologies9SiteSurveys) <br/><br/>
#     * [Types](#wirelessTechnologies9SiteSurveysTypes) <br/><br/>
#         * [Passive](#wirelessTechnologies9SiteSurveysPassive) <br/><br/>
#         * [Active](#wirelessTechnologies9SiteSurveysActive) <br/><br/>
#         * [Predictive](#wirelessTechnologies9SiteSurveysPredictive) <br/><br/>
#     * [Documentation](#wirelessTechnologies9SiteSurveysDocumentation) <br/><br/>
#         * [Map](#wirelessTechnologies9SiteSurveysMap) <br/><br/>
#     * [Cellular Site Survey Documentation](#wirelessTechnologies9SiteSurveysCellularSiteSurveyDocumentation)

# %% [markdown]
# ### [Practice: Configure Wireless Standards](#configureWirelessStandards) &#x1F6A7;
#
# * [1. Exercise: Configure Wireless Standards](#configureWirelessStandardsconfigureWirelessStandards)

# %% [markdown]
# <a id="topWirelessTechnologiesTest"></a>
# ### ⚡ [Test](#wirelessTechnologiesTest)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies"></a>
# ***
# ### Wireless Technologies
# ***

# %% [markdown]
# Earlier, we touched on some of the basic characteristics of wireless communications as defined by the 802.11 specification. But that was quite some time ago, and there have been a number of enhancements and refinements to that specification since. So in this presentation, we'll take a look at several of them, beginning with 802.11a.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards"></a>
# ***
# ###### 1. 802.11 Standards
# ***

# %% [markdown]
# Earlier, we touched on some of the basic characteristics of wireless communications as defined by the 802.11 specification. But that was quite some time ago, and there have been a number of enhancements and refinements to that specification since. So in this presentation, we'll take a look at several of them, beginning with 802.11a.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards80211a"></a>
# ***
# ###### 802.11a
# ***

# %% [markdown]
# [802.11a.] Now this was created as an extension to the original 802.11 standard and supports a higher bandwidth, up to 54 megabits per second and a frequency spectrum around 5 gigahertz. Now that higher frequency does offer a better quality signal, but by nature, higher frequencies do not travel as far as lower ones do. So it shortens the range of a networks, and further, the higher frequency makes the a signals more difficult to penetrate obstructions, such as walls. Now that's not necessarily a downside, if you will. Sometimes you might actually want to restrict the network a little bit more, condense it, if you will, or confine it to a shorter range. And if it's more difficult to get through things like walls, that might actually provide a little more security.

# %% [markdown]
# So again, depending on your perspective, it might not really be a downside. So in terms of the pros, it does offer that higher speed and the use of regulated frequencies, meaning that other devices do not use this frequency. It has effectively been reserved, so this prevents signal interference.

# %% [markdown]
# But on the downside, it can cost more and again, can shorten the range and be more easily obstructed. So if you are looking for a wider range that penetrates more easily, then yes, this is certainly a con.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards80211b"></a>
# ***
# ###### 802.11b
# ***

# %% [markdown]
# [802.11b.] Now b, supports bandwidths of up to 11 megabits per second. So considerably slower, this is comparable to the traditional Ethernet around 10 megabits per second. And that, in and of itself, is quite old these days. And it also uses unregulated 2.4 gigahertz signaling frequency, meaning a lot of vendors, a lot of devices use the same frequency. But since it is very commonly produced, this can lower the production costs. So ultimately, it can incur interference from devices using the same 2.4 gigahertz range. Some common examples are microwaves ovens, cordless phones, and various other appliances. So they can disrupt the signals.

# %% [markdown]
# So in terms of the pros, it is a lower cost, and it has that better range. And it's not as easily obstructed.

# %% [markdown]
# But on the cons side, it is the slowest maximum speed. And again, susceptible to interference because of that unregulated frequency band. So you might think well, if it's not as fast as ``a``, and it suffers from possible interference, and simply the fact that it uses the letter ``b``, you might think that it came out after a. In fact, a and b were released at the same time, and it really just comes down to what you prefer. If you want the lower cost and the better range, you went with b. But there was the tradeoff in that it wasn't as fast. But a was faster, but more easily obstructed and things along those lines, didn't travel as far. So there was always the tradeoff in either case.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards80211g"></a>
# ***
# ###### 802.11g
# ***

# %% [markdown]
# [802.11g.] So along came g, which emerged in 2002 and 2003, and this combines the best of both ``a`` and ``b``. It supports the higher bandwidth of up to 54 megabits per second, but uses the 2.4 gigahertz frequency for greater range. This was also backward compatible, in other words, it worked with the already in place b wireless adapters that you might have had. So we don't have to change out all of our adapters to take advantage of the higher speed.

# %% [markdown]
# In terms of the pros, you get that fast maximum speed, again up to 54 megabits per second. You get good signal range, which is not easily obstructed, but it could have been more expensive than the b that was already implemented. Plus, since you did already implement the b, you are looking at basically junking all of that and incurring the extra cost of a new infrastructure. Plus, it still might suffer from the interference, because it was using 2.4 gigahertz.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards80211n"></a>
# ***
# ###### 802.11n
# ***

# %% [markdown]
# [802.11n.] So then n came along. This was often referred to as just Wireless N. But this improves on ``g`` by offering greater bandwidth and utilizing multiple wireless signals and antennas instead of just one. This is known as MIMO technology, which we will actually talk about later on. Very quick and short, it is multiple antennas as opposed to just one. A lot of the early wireless routers had a single antenna. So this can support bandwidths of up to 300 megabits per second and a better range and increased signal intensity.

# %% [markdown]
# So in terms of the pros, we now have the fastest maximum speed, 300 megabits per second, the best signal range, and the most resistant to signal interference, and it's still backward compatible. Cons, the standard is not yet finalized, so it may affect things moving forward. And again, it's more expensive than 802.11g.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies180211Standards80211ac"></a>
# ***
# ###### 802.11ac
# ***

# %% [markdown]
# [802.11ac.] Then we have 802.11ac, which is the newest generation of Wi-Fi signaling. This utilizes dual band wireless technology, which means it supports simultaneous connections over both 2.4 and 5 gigahertz. It is backward compatible with ``802.11b``, ``g``, and ``n``. And supports bandwidths that have been rated up to 1,300 megabits per second on 5 gigahertz and 450 megabits per second on 2.4. So significantly higher, in fact in both cases, using either frequency. So again, this really pulls together the best of everything, but this can certainly be a little more expensive as well, and does represent yet another upgrade. So if you have already implemented your existing infrastructure with something else, once again, you are looking at another upgrade. So there certainly can be those downsides as well. Ultimately, you just want to try to ensure that you have good range, good signal quality, good speed, and of course, security, but at the same time, while not having to continually upgrade and incur additional costs.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies2CellularTechnologies"></a>
# ***
# ###### 2. Cellular Technologies
# ***

# %% [markdown]
# In this presentation, we'll take an introductory look at some of the types of mobile or cellular communications, beginning with what's known as GSM.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies2CellularTechnologiesGSM"></a>
# ***
# ###### GSM
# ***

# %% [markdown]
# GSM - Global System for Mobile communication. This is a digital mobile telephony system that currently represents over 82% [precisely 82.4%.] of all global mobile connections. Now, it operates at one of two frequencies, 900 or 1800 MHz. And, of course, fundamentally, just digitizes and compresses data prior to sending it down a channel. But one of the inherent challenges is, of course, the tremendous number of people using mobile communications these days. There are billions worldwide. Now, of course, not all of us are communicating at the same time using the same towers. But there are still quite a few at any given time. So we need a way to better accommodate multiple users.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies2CellularTechnologiesTimeDivisionMultipleAccessTDMA"></a>
# ***
# ###### Time Division Multiple Access - TDMA
# ***

# %% [markdown]
# [TDMA.] And one approach is what's known as TDMA, Time Division Multiple Access. Again, multiple people using the same media at the same time. So this is a technology used in digital cellular communication, whereby the channels are divided into three time slots. This increases the amount of data that can be carried, essentially, threefold. Now, this is used by Digital-Advanced Mobile Phone Services, or D-AMPS, GSM [Global System for Mobile communications.] that we just talked about, and Personal Digital Cellular, [abbreviated as PDC.] those are just different types. And D-AMPS and PDC, in essence, make up the remaining percentage of communications.

# %% [markdown]
# But the idea behind TDMA is that each channel, and there are a tremendous number of channels available, is divided by time. And then each user or each device synchronizes to that time. So when I'm communicating, I use time slot A. When you are communicating, you use time slot B, and someone else uses C. And we only pay attention, if you will, to the data in our specific time slots. So I don't hear your conversation, you don't hear mine, because of the difference in the time slots. Now this does require some pretty specific synchronization, but voice data is not all that much. So, in other words, it's not a big deal to break it up into these smaller chunks, if you will. And it accommodates multiple users on the same channel. So, again, we can increase the overall throughput three times per channel.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies2CellularTechnologiesCodeDivisionMultipleAccessCDMA"></a>
# ***
# ###### Code Division Multiple Access - CDMA
# ***

# %% [markdown]
# [CDMA.] Now another method of accommodating that multiple access is CDMA, or Code Division Multiple Access. This is used in second-generation, 2G, and third-generation, 3G, wireless communications. And I'm certain, if you have a mobile device, you are very familiar with what we call 3G. So this is just another form of multiplexing which allows numerous signals on a single transmission channel. And this optimizes the available bandwidth. It's commonly used in ultra-high frequency cellular systems running at either 800 MHz and 1.9 GHz. But the idea is that each transmission has a specific code attached to it. And your device is programmed, for lack of a better word, to only pay attention to the specific code that matches your connection. So again, my conversation uses Code 1. Your conversation uses Code 2. We only pay attention to the appropriate code. So, again, I do not hear your conversation, you do not hear mine. So, this way, again, we can facilitate multiple access over the same channel.

# %% [markdown]
# So in terms of the benefits, this offers good quality signal, there's no division in terms of the time, so the signal quality is a little better. It offers flexible allocation of resources. It's easy scalable because you can just add more codes. And it's compatible with other cellular technologies.

# %% [markdown]
# Disadvantages, as the network grows, overall quality of service decreases. If you end up with too many codes, that's a lot of processing. So the more devices, the more codes you need to maintain and manage. So, in essence, it can become a bottleneck. But ultimately, that is how, these days, we facilitate the multiple access requirements of cellular communications.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3Frequencies"></a>
# ***
# ###### 3. Frequencies
# ***

# %% [markdown]
# In this presentation, we'll talk about frequency with respect to wireless communications. And ultimately, how it affects the overall amount of data that can be transmitted, as well as some other characteristics.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequency"></a>
# ***
# ###### Frequency
# ***

# %% [markdown]
# [Frequency.] But the term itself quite simply represents the number of complete cycles in a single second. And I'm sure that's nothing particularly new. We've been using this term in various components of computing for a very long time. For example, our processors. We always describe them as being 3 GHz processors, for example. That means they can process 3 billion times per second. And in terms of wireless communications, the 2.4 GHz frequency means it cycles 2.4 billion times per second. So again, it is quite simply how often something occurs. Now, in terms of radio transmissions, lower frequencies correspond to a longer radio wavelength. The length is the distance between the 2 peaks or the 2 troughs, for example.

# %% [markdown]
# So if you imagine that graphic as a bit of a spring, and you grab hold of the end and you stretch it out, you are increasing the distance between the peaks or the troughs. That is a lower frequency. It's happening less often within the same space. So the space between them gets longer.

# %% [markdown]
# Conversely, higher frequencies corresponds to a shorter radio wavelength. So again, if you'll imagine that as a spring, then you would squash it in. And you would decrease the distance between the peaks or the troughs, so again, a shorter wavelength. Ultimately, it is quite simply how many of those peaks or troughs occur in one second that dictates the frequency.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification"></a>
# ***
# ###### IEEE 802.11 Specification
# ***

# %% [markdown]
# Now when it comes to wireless communications, this was defined by the IEEE 802.11 specification. And it operates in several unlicensed frequency ranges. Now, this is actually quite important. You see 2.4 GHz there, and that has, for a very long time, been a standard, but it's actually not always exactly 2.4 GHz. There is a range between 2.4 and 2.5 that is actually used. And there are varying values within that range for different types of transmissions.

# %% [markdown]
# Now, we'll talk about that in greater detail later on, but it is not always exactly 2.4.

# %% [markdown]
# And the same thing goes for the 5, we call it 5 GHz, but it's actually 5.15 up to 5.875. And the unlicensed component, in essence, means that it's not reserved. There are other things that can use those same frequency bands, if necessary. There are certain transmissions that are licensed. They are reserved and nothing else is allowed to transmit on those frequencies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHz"></a>
# ***
# ###### 2.4 GHz
# ***

# %% [markdown]
# [2.4 GHz.] So looking at the 2.4 GHz standard, this is, in essence, ``802.11b``, ``g``, and ``n``.

# %% [markdown]
# And you can see that the speed changes. For b, it only supported 11 Mbps, for g, 54 Mbps, and for n, up to 150 Mbps on a 20 MHz channel width. And then 300 for a 40 MHz channel width. Now, we'll talk about that in greater detail later on as well, the channel width. But you can see, despite the math here, that when you double the size of the channel, you double the overall throughput. So this is why you see varying Mbps values from b to g to n. It's not just the frequency itself, but the channel over which it is carried and how wide that channel is.

# %% [markdown]
# Imagine a channel like a highway. If it's a two lane highway, it can handle x amount of traffic. But if it's a four lane highway, we can imagine it can handle twice as much traffic. 2.4 GHz, again, is the standard for 802.11b, g, and n with varying speeds.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHzAdvantages"></a>
# ***
# ###### Advantages
# ***

# %% [markdown]
# Now 2.4 has the advantages of a wider signal coverage. It can travel farther, lower frequencies simply travel farther than higher ones do by nature. And they're better at penetrating walls or other barriers or obstructions, and it supports Wi-Fi ``b``, ``g``, and ``n``, so it's fairly compatible.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification24GHzDisadvantages"></a>
# ***
# ###### Disadvantages
# ***

# %% [markdown]
# But, in terms of disadvantages, there can be possible congestion and interference. Other devices, such as microwaves, Bluetooth devices, cordless phones, all might be using that same frequency range. So they can quite literally interfere with each other.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHz"></a>
# ***
# ###### 5 GHz
# ***

# %% [markdown]
# [5 GHz.] So then, the 5 GHz standard is used in ``802.11a``, ``n``, and ``ac``. And again, we see varying speeds depending on each specification. A, up to 54 Mbps, n, up to 150 on a 20 MHz channel. And then we see, again, the same doubling factor here, 300 Mbps if it's on a 40 MHz channel. Then ac, in theory, can reach speeds of up to 6.8 Gbps with 8 antennas, all running at 160 MHtz channel width.

# %% [markdown]
# So again, that's not particularly common in any kind of practical implementation yet. But it does actually have that capability.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHzAdvantages"></a>
# ***
# ###### Advantages
# ***

# %% [markdown]
# So advantages of the 5 GHz band. It is less congested and there's less interference. It's not as susceptible, because there aren't as many devices using that same frequency. It supports 23 non-overlapping channels, so again, those lanes don't overlap with each other, they don't interfere. And it supports higher network speeds, particularly, when using the 802.11ac, as we just saw.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies3FrequenciesFrequencyIEEE80211Specification5GHzDisadvantages"></a>
# ***
# ###### Disadvantages
# ***

# %% [markdown]
# But disadvantages, it's a smaller signal area. The signals do not travel as far, nor do they penetrate as well. It also may not support older devices, so it's not as compatible. But moving forward, I think you will probably see more 5 GHtz than 2.4 because of the speed advantage. And that's typically what we want to see these days. We always sort of assume that faster is better, but not in every situation. So again, the frequency itself really just comes down to how many times per second that signal goes from its peak to its trough and back again. And those two different frequency bands have different advantages and different disadvantages. Depending on their implementation and depending on which characteristic you feel is most desirable.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies4SpeedandDistanceRequirements"></a>
# ***
# ###### 4. Speed and Distance Requirements
# ***

# %% [markdown]
# In this presentation, we'll take a look at the speed and distance requirements of wireless communications as defined by the IEEE standard of 802.11. [Speed and Distance Requirements.]

# %% [markdown]
# Now, to begin, this is the original 802.11, no letter after the number. And recall, this was quite some time ago, 802 refers to February of 1980. So when it was originally defined, the frequency was 2.4 GHz. The speed was only 1 to 2 Mbps, and the transmission range was only 20 feet indoors. So quite limiting by today's standards.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies4SpeedandDistanceRequirements80211a"></a>
# ***
# ###### 802.11a
# ***

# %% [markdown]
# But as technology improved and as protocols were refined, we saw 802.11a come out. And this used a frequency of 5 GHz with a speed of up to 54 Mbps, and a transmission range of 25 to 75 feet. So that was certainly a lot better in terms of speed and distance. But the range could certainly be affected by obstructions.

# %% [markdown]
# Now, that's true of any radio communications. The more obstructions and the larger they are, then the less you will receive that signal. But recall that 5 GHz frequencies were more easily affected by obstructions than were the 2.4 GHz frequencies.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies4SpeedandDistanceRequirements80211b"></a>
# ***
# ###### 802.11b
# ***

# %% [markdown]
# So then b, released at the same time as a, was still using the 2.4 GHz frequency, but only supported speeds of 11 Mbps. But you can see the range was significantly better, up to 150 feet indoors. Now, again, that can still be effected by obstruction. But while it's not as fast as a, it traveled much farther. So there were pros and cons of each one.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies4SpeedandDistanceRequirements80211g"></a>
# ***
# ###### 802.11g
# ***

# %% [markdown]
# Then we see 11g. Again, using the 2.4 GHz frequency, but now we have speeds of 54 Mbps, so comparable to a. And we still have a very good transmission range, up to 150 feet indoors. [Range can be affected by obstruction.]

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies4SpeedandDistanceRequirements80211n"></a>
# ***
# ###### 802.11n
# ***

# %% [markdown]
# And then finally, n supported both frequencies, 2.4 and 5, and a speed of up to 600 Mbps, depending on the channel configuration. And a transmission range of up to 175 feet indoors. Again, possibly affected by obstruction. But I would imagine that moving forward, we will continue to see enhancements and refinements. And, really, the speed should only get faster and the range should only get farther. But, in some cases, you need that backward compatibility. So there's always a little bit of compromise, if you will. But these enhancements and refinements typically tend to just keep improving the overall transmission. So I think we'll see many more letters yet to come.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies5ChannelBandwidth"></a>
# ***
# ###### 5. Channel Bandwidth
# ***

# %% [markdown]
# In this presentation, we'll take a closer look at channel bandwidth. And this is something I referred to earlier, when I mentioned how channels more or less equate to lanes on a highway, and the more lanes you have, the more traffic you can handle. So in terms of data rates, your speed, can be directly affected by the channel bandwidth of a wireless signal.

# %% [markdown]
# Now we see two examples here, 802.11n using 20 or 40 MHz channels and 802.11ac using 20,40, 80, and 160 MHz channels. Now, n uses the core frequency of 2.4 GHz. And ac, the core frequency of 5 GHz. But the question I get quite often is, well, what are these two hertz values? I thought the transmission was 2.4 GHz or 5 GHz depending on your implementation. Why am I seeing this megahertz values on the channels?

# %% [markdown]
# Well, that comes down to the basic fact that anything measured in hertz, recall, is simply a measure of how often something happens.

# %% [markdown]
# So the core frequencies 2.4 GHz and 5 GHz are certainly correct. You send out a signal using that frequency. That refers to the waves, how often those waves happen in one second. But then you have to consider how often you can send that signal. So let me give you a simpler example.

# %% [markdown]
# If you just speak a word, let's say the word hello, that word produces sound waves, and those sound waves come out at a specific frequency. It doesn't what it is, let's just call it frequency x. So you say the word hello, you just sent a signal, and the sound waves came out at frequency x. But you can, of course, say that word again and again and again and again. So how many times you can say that word within one second refers to another measure in hertz, how many times can you send that information? So that's where the channel comes in. The more often you can say it, the more information you are transmitting. So that's where the channels allow for x amount of data depending on how often they can support that core transmission.

# %% [markdown]
# So, again, the signal itself, the core data, is being sent out at, let's say 2.4 GHz. So the channels then, are how many times you can send that transmission across that channel. So those are the two separate hertz values. And clearly, the more megahertz you have per channel, the more times, if you will, you can send that signal. So you end up with higher bandwidth overall.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies5ChannelBandwidthChannelWidth"></a>
# ***
# ###### Channel Width
# ***

# %% [markdown]
# [Channel Width.] Now Wi-Fi networks, of course, use the frequency or the channels to transmit and receive data, as we know.

# %% [markdown]
# And by default, the following channels are used, 6 and 11.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So if you look at the configuration of some of those wireless routers, for example, very likely you would see those channels. And that might seem somewhat arbitrary, but there is a reason. And it comes down to the fact that the core frequencies themselves of 2.4 GHz and 5 GHz, recall from earlier, are not exactly those values. The 2.4 GHz specification actually ranges from 2.4 up to close to 2.5. It actually caps out around 2.78 or something along those lines, I can't remember exactly, but the point is, there is a variance.

# %% [markdown]
# And the same goes with the 5 GHz, and again, we saw those in an earlier presentation. It ranges from 5.1 up to about 5.8 something. Again, the value themselves don't entirely matter at this point. It's really just coming down to the fact that there is this variance of frequencies.

# %% [markdown]
# So when we talked about 2.4 and 5, they aren't exactly those values. There is this variance. So if we have these devices transmitting on Channel 6, it does not actually look like above, where you see everything going down one channel.

# %% [markdown]
# Because of the variance, it actually looks like this, where you see some of it, for lack of a better word, leaking out onto either side of the core channel. So because of those variances in the frequency, using Channel 6 actually utilizes 4, 5, 6, 7, and 8.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So it's fine to have these devices on the same channel, but you are trying to cram more traffic down the same lane of that highway. Even though it spreads it across five channels, it's basically still the same five lanes of the highway. Now again, it just comes down to the total amount of bandwidth that you need as to whether or not this is a good idea. There's no harm in this, per se, but if you find things are getting a little bit bogged down, you can simply change the channel. So if you were to change one of the devices to Channel 7, for example, you might think you've accomplished your goal. One of them is on 6, one of them is on 7, everybody's happy. But because of that variance, because of the spread, moving one to Channel 7, in fact, would not really accomplish the goal because you'd be using 5 through 9 instead of 4 through 8.

# %% [markdown]
# So you'd have a little bit that would be on its own dedicated channel, but not very much. So the farther away you move it, the less overlap there will be. And, ultimately, if you are going to do this then what you would want to do is something like this, moving it to Channel 11.

# %% [markdown]
# That's why you see 6 and 11 used by default. Because since they both spread over five channels, going all the way to 11 ensures that we start at 9, whereas, the other routers end at 8.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# So ultimately, again, it really comes down to if you feel this is even necessary. Again, there's no harm in using the same channel, but by the same token there's no harm in using a different channel. But you've got a little bit of extra configuration now because the other systems communicating with each router also have to have their channels adjusted. Not a big deal in a smaller environment, if you are only talking about a handful of systems. Then it's no big deal to set some of them to Channel 6 and some of them to 11. But then they also have been dedicated to those devices and that might be a good thing. But if they're somewhat physically separated and the people are moving around and they end up connecting from router 1 to router 2, and their channel has been specifically set to use Channel 6 let's say, it won't be able to connect to the other router. It's a different channel.

# %% [markdown]
# So there are considerations, of course. If you need mobility and people to be able to connect to any of those routers without changing anything, then they should all be set to the same channel. But if you are absolutely trying to segregate this traffic and you only want those clients to connect to that router and these clients to connect to a different router, then that's perfectly fine. You would isolate that traffic and you would ensure that they don't interfere with each other. And they would always connect to the same router because they have the correct channel set. So there are always considerations, but that is the basic idea overall with respect to setting those channels and allocating and/or determining the overall bandwidth available.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies6ChannelBonding"></a>
# ***
# ###### 6. Channel Bonding
# ***

# %% [markdown]
# Now, in this presentation, we'll take a look at what's known as channel bonding. [Channel Bonding.] And this is commonly used in IEEE 802.11, or wireless communications. And is the process of taking two adjacent channels using different frequencies and combining them. This, of course, increases the overall throughput between those devices.

# %% [markdown]
# Now, we actually touched on this earlier when we looked at the various specifications of 802.11, the a, b, g, n, and ac, and we saw various throughputs, of course. But for the most part, if we saw a throughput of x on a 20 MHz channel, then, of course, you could get a throughput of 2x on a 40 MHz channel. So those widths of 20 MHz per channel were established quite sometime ago in wireless communications. But there's nothing that prevents us from taking two of them and putting them together and creating a 40 MHz width. But of course, what happens here, let's just go with very easy numbers and let's imagine we only had two available to begin with, then clearly, you are reducing the number of channels.

# %% [markdown]
# If you take those two and put them together to create one, well, now you only have one channel. So you will inherently have fewer channels when you bond. But if you aren't concerned with the number of channels and are really only concerned with the throughput, then, of course, bonding is the way to go.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, this was very popular in Wi-Fi implementations and remains so as it provides additional functionality for what you can support. And, of course, that overall increased throughput, and this was initially released with 802.11n.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies6ChannelBonding24GHz"></a>
# ***
# ###### 2.4 GHz
# ***

# %% [markdown]
# Now, that said, there are some considerations with respect to the frequency. If you are using the 2.4 GHz frequency band, then you can only support three non-overlapping 20 MHz channels. Recall that we also talked about the 2.4 GHz band and the 5 GHz band earlier. And it's not exactly 2.4 GHz, it ranges from about 2.41 to about 2.47 in fact. And this gives you a total width of approximately 70 MHz, it might vary a little bit. But if you only have 70 MHz in total and each channel is 20 MHz wide, then you can only have a single bonded pair of 40 MHz. The remainder of that band is only 30 MHz wide, so you cannot create a bonded pair of 40 when there's only 30 left.

# %% [markdown]
# So that said, it still does give you the increased throughput because you do at least now have one bonded channel. So this does offer a throughput of up to 54 Mbps.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies6ChannelBonding5GHz"></a>
# ***
# ###### 5 GHz
# ***

# %% [markdown]
# But if you look at the 5 GHz frequency band, there is in fact a much wider range. The 5 GHz goes from about 5.1 to about 5.8, but it's not entirely contiguous. There are some areas in between that are kind of reserved, if you will, for other types of communications. But you can have up to 25 non-overlapping 20 MHz channels within the band, because the total width is somewhere in the range of about 500 MHz of the usable space. So many more bonded pairs can be configured, in fact, up to 160. So that's taking two 20s to make a 40, then two 40s to make an 80, then two 80s to make a 160. So when you have a channel that wide, which is configurable in 802.11ac, then you start to see those very high throughput values that are up into the gigabits per second range. So significantly more throughput, of course. So channel bonding is, in most cases, far more flexible within the 5 GHz band as compared to the 2.4 GHz band. But it is still supported, you just have a little more flexibility and, of course, the greater throughput if you configure this within the 5 GHz band.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies7MIMOMUMIMO"></a>
# ***
# ###### 7. MIMO/MU-MIMO
# ***

# %% [markdown]
# In this presentation we'll take a look at MIMO or Multiple Input Multiple Output.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies7MIMOMUMIMOMIMO"></a>
# ***
# ###### Multiple Input Multiple Output - MIMO
# ***

# %% [markdown]
# [MIMO.] And this is actually an antenna technology for wireless communications whereby you can send multiple signals at once using an array of antennas. Now, these multiple antennas are combined at each end of the circuit. And with respect to each end, it doesn't refer to the fact that there is one on the left and one on the right of something like a wireless router, but rather multiple antennas at the transmitter, multiple antennas at the receiver. So by using these multiple signals you can minimize errors and optimize your data speed. Now this is supported by 802.11n and ac.

# %% [markdown]
# And fundamentally, it's taking into consideration the fact that electromagnetic signals bounce off walls and other obstructions and hence can take different paths from device to device. They are quite literally echoing if you will. So this causes delays and increased errors with respect to any given transmission. So by using multiple signals over those multiple antennas you get greater reliability and greater throughput overall.

# %% [markdown]
# Now it should also be mentioned that what we are seeing in the graphic here is what's known as single session or single user MIMO. It does not mean that you cannot have multiple users connected. Since the earliest days of wireless networking you, of course, could have more than one user connected. But it just means that it kind of has to deal with each session, one at a time. So as far as the router is concerned, for example, it sees sessions 1 through 3. And you can imagine this as trying to have different conversations with three different people. You can do it, but you have to move from person to person to person. So each person gets their own turn, if you will, with respect to the communication, so clearly it's not as fast.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies7MIMOMUMIMOMUMIMO"></a>
# ***
# ###### Multi-User MIMO
# ***

# %% [markdown]
# [MU-MIMO.] So Multi-User MIMO was introduced to, in essence, address that issue. This is an enhanced form of MIMO. And it enables multiple independent radio terminals to access a system. So, it uses various algorithms and various methods of multiplexing to effectively allow simultaneous communication with multiple users. And you can see it can actually still use both. It can use the single session capabilities if, and/or when necessary so we see sections 1 and 2 actually being dealt with separately.

# %% [markdown]
# Then we see 3 and 4 are basically on their own, if you will. So 1, 2 are combined. Then 3 and 4 are independent. But all of this is happening at the same time. So, with this now we've got multiple radio terminals, they can provide significant performance enhancement. Because we now have these multiple users simultaneously accessing the same channel. So with this we can get significantly higher data rates. For example in 802.11ac, the increased theoretical maximum speed is anywhere from 3.47 gigabits per second up to 6.93. Now you probably won't see those in practical implementations. Those are laboratory tests if you will where everything is perfect. But clearly with this multi-user capability and the ability to have these simultaneous conversations if you will, the overall throughput can be dramatically increased.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennas"></a>
# ***
# ###### 8. Unidirectional vs. Omnidirectional Antennas
# ***

# %% [markdown]
# In this presentation, we'll take a look at some of the characteristics of the different types of antennas that are used in wireless communications.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasAntennas"></a>
# ***
# ###### Antennas
# ***

# %% [markdown]
# [Antennas.] Now fundamentally, a radio antenna is used to transmit or receive radio signals by converting electric power into electromagnetic, or radio waves. Now of course, antennas can be huge structures, such as the cellphone transmission towers we often see on the horizon or tiny enough to fit into a cellphone. So of course, depending on the device, that will determine the appropriate size and/or type of antenna.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasOmnidirectionalAntennas"></a>
# ***
# ###### Omnidirectional Antennas
# ***

# %% [markdown]
# [Omnidirectional Antennas.] So the main characteristic really is the direction of transmission, so there are several categories here. The omnidirectional antennas transmit and receive with equal efficiency in all directions. The waves effectively emanate out in a sphere. So examples include, radio transmission towers and cellphone antennas. And they have the advantage of being easy to install, they can be mounted virtually anywhere and in any direction.

# %% [markdown]
# And again, really in any size, depending on how it's being used. In terms of things like networking or maybe even more specifically stated home networking. We, of course, are all familiar with the wireless routers, which have the two antennas on them in most cases. But there is a disadvantage, that they typically have a shorter range due to the signal being spread so broadly. For all intents and purposes, there is an awful lot of the signal that is wasted, if you will. There's a huge volume of signal that just is not picked up by any particular device. So the range is not as good, and their efficiency is not all that high.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasDirectionalAntennas"></a>
# ***
# ###### Directional Antennas
# ***

# %% [markdown]
# [Directional Antennas.] So then, directional antennas have a narrow, more focused directional signal. By design, these types of antennas work more effectively in some directions compared to others. So they are not only a little more effective in any given direction, but more efficient because there isn't that wasted transmission, if you will.

# %% [markdown]
# So the advantages, can offer improved transmission, improved reception of communication. And reduced interference, because they are more targeted, more focused. But it can have the disadvantage of effectively being decreased in terms of its width. In other words, if you need that very broad coverage, then directional antennas don't do the job, they are more focused. So again, it depends on the application, really, with respect to is that an advantage or a disadvantage? Now, with in the directional, there is also what's referred to as semi directional. Wherein it direct a signal over an arc to reduce unnecessary power usage. Again, just trying to limit the wasted amount of any given signal. Now, I mentioned earlier that the signal emanates out in a sphere, but let's imagine it just more so as a circle in a single plane. If it was omnidirectional across a single plane, the signal would cover 360 degrees. Semi-directional focuses a part of that circle, so that it's only maybe 180 degrees. For example, half of the circle or maybe even less than that. You can focus them, in a lot of cases, however is necessary.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasBidirectionalAntennas"></a>
# ***
# ###### Bidirectional Antennas
# ***

# %% [markdown]
# And bidirectional antennas would have two high power directions. So again using the 360 degree example, you could configure a bidirectional to focus one signal for the forward facing 180 degrees. And then another one for the backward facing 180 degrees. But you could use them separately. And again, the degree of coverage is actually configurable in most cases.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasYagiUdaAntennas"></a>
# ***
# ###### Yagi-Uda Antennas
# ***

# %% [markdown]
# [Yagi-Uda Antennas.] Then there is the Yagi-Uda antenna, sometimes just called a Yagi. They have a distinctive arrangement of parallel elements. And this is used as a highly directional antenna, often used for fixed point to point systems. And you may have seen this if you've ever watched a nature program where they are tracking a tagged animal. They almost always use this kind of antenna. Very focused, very directional, so it's very good picking up on a signal once it is able to establish a connection with the specific direction of the transmission.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies8UnidirectionalvsOmnidirectionalAntennasParabolicDishAntennas"></a>
# ***
# ###### Parabolic Dish Antennas
# ***

# %% [markdown]
# [Parabolic Dish Antennas.] And finally, we have the parabolic dish antennas, whereby the parabola is used to focus incoming signals to a point. So it could pick up on a fairly broad range of signals, but then it focuses them. And of course, this is used in satellite communications and other long range directional applications. So it's certainly not omnidirectional, nor is it uni.

# %% [markdown]
# But typically, you get a fairly focused portion of that spectrum that is picked up by the parabola and then again sent directly to that single point for processing. So ultimately, the type of antenna is dependent on the device and/or the application, but they all have their specific purposes. So depending on what you need to accomplish with your transmission, that will determine the appropriate type of antenna.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveys"></a>
# ***
# ###### 9. Site Surveys
# ***

# %% [markdown]
# In this presentation, we'll take a look at what's known as site surveys for wireless networks.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysTypes"></a>
# ***
# ###### Types
# ***

# %% [markdown]
# And there are different types depending on what you're looking for and where you are in your implementation. In other words, you might be assessing an existing wireless network or considering a new implementation.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysPassive"></a>
# ***
# ###### Passive
# ***

# %% [markdown]
# [Site Survey Types.] So the first type is known as passive. This assesses the existing access points for signal strength, interference, and access point coverage. And provides a good overall picture of the radio frequency characteristics of an existing wireless network. Now when performing a passive, there is no actual connection to the access points. You're basically just gathering up very general statistical information about how far the signal carries and what is interfering and things along those lines. So you don't actually establish a connection.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysActive"></a>
# ***
# ###### Active
# ***

# %% [markdown]
# And that differs from the active, this gathers very detailed information because you do actually make a connection to the access points. So with this, you get actual network traffic patterns. You can assess the overall throughput and packet loss, and determine the actual physical rates.

# %% [markdown]
# So again, a passive, very general, just in essence, getting the basics. Then the active you actually establish the connection and gather that much more detailed information.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysPredictive"></a>
# ***
# ###### Predictive
# ***

# %% [markdown]
# Then the third type is the predictive. This is performed without any type of field measurement and effectively, this is when you are considering a new implementation, rather than assessing an existing one. This uses RF planning software to predict the wireless coverage. So in essence, this is done at an architectural level. Often used when the site or the building is not even built yet. So this is helpful for budgeting and planning, of course. So, in order to do this, you need some kind of floor plan drawing. Either something in AutoCAD, or a PDF or a JPEG that can effectively be fed into the software. And then you just use various placements to see what the results might be, just in a virtual configuration.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysDocumentation"></a>
# ***
# ###### Documentation
# ***

# %% [markdown]
# [Site Survey Documentation.] So from that point, the next step is documentation. Documenting your findings of any given survey is crucial and it would take a lot of work to recreate if they were not accurately recorded. So you need to keep track of everything and you need to be able to produce something. And those findings might also be needed for regulatory reasons.

# %% [markdown]
# For example, industry or government specific industry regulations that dictate this must be in place and this criteria must be met. And that specification must be adhered to. So the main output then of a survey is the site survey report. Again, this is the official documentation. And the report should include things like site maps, recommendations such as the actual network layout. And of course, the potential issues that might arise with respect to the coverage, the capacity, and any interference.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysMap"></a>
# ***
# ###### Map
# ***

# %% [markdown]
# [Site Survey Map.] The survey map should include any notable locations and materials, particularly a heat map of signal strength. In other words, where is the best signal, where is the weakest signal. So that of course is based on your access point placement, but it simply shows graphically where the signal is at its best and where it's at its worst. So you can obviously avoid placing systems where there is very poor signal. A site map should also include existing network coverage and potential future coverage after the recommendations are implemented. Of course, if this is a scenario where you have assessed an existing site.

# %% [markdown]
# So if it's just being modified, basically you are saying, here's what we have, here's what we should do. And basically, you know, lay out what that would look like.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologies9SiteSurveysCellularSiteSurveyDocumentation"></a>
# ***
# ###### Cellular Site Survey Documentation
# ***

# %% [markdown]
# [Cellular Site Survey Documentation.] Now, you might also include in this cellular site surveys but the documentation, while it should be similar, might not be particularly informative. In other words, the recommendations can be rather limited because much of the configuration is simply out of your control. So you can make suggestions such as changing to a different provider. Mapping out that this provider looks like that and this provider looks like this. So that one looks better, let's go that route. And if that's the case, the coverage gaps and the heat maps should be included to justify that recommendation. You know, be able to show that if we change to provider y from provider x, this is the coverage we will get. So again, you can certainly make those recommendations but in many cases, it is out of your control. But ultimately, it is just trying to get as good a picture as possible of any given site, and how wireless transmissions will behave within that site.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="configureWirelessStandards"></a>
# ***
# ### Practice: Configure Wireless Standards
# ***

# %% [markdown]
# &#x1F6A7;

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="configureWirelessStandardsconfigureWirelessStandards"></a>
# ***
# ###### 1. Exercise: Configure Wireless Standards
# ***

# %% [markdown]
# Okay, in our exercise this time, we'll ask you to describe the 802.11 standards. Then to describe cellular technologies. Then speed and distance requirements. And finally, channel bonding. So again, what we'd like you to do is to take a few minutes, pause the recording, jot down some responses. And then we'll come back to review, and see how you made out. So we'll see you shortly. All right, so for our review, we first asked about the 802.11 standards. And there are several, as defined by 802.11a, b, g, n, and ac. And each one varies in frequency, bandwidth, range and compatibility. Now, g, n, and ac are the newer ones for sure, and do accommodate the fastest speeds and the more stable frequencies, but there are always compromises. Sometimes, you want better distance or coverage. Sometimes you want faster speed, sometimes you need compatibility. So it comes down to which components, which characteristics are of the greatest value to you.
#
# So really just become familiar with the characteristics of each before implementing any kind of wireless configuration. Then we asked about cellular technologies. And primarily, we talked about the Global System for Mobile communications, or GSM. And certainly because of the numbers of people that are using mobile communications these days, we need to come up with some form of multiple access. And in GSM, this is accomplished using either TDMA, Time-Division Multiple Access, or CDMA, Code-Division Multiple Access. Each one, in essence, uses some kind of scheme to separate my communications from yours. So that we don't overlap, and we can take advantage of this same media at the same time. Then with respect to speed and distance requirements, this is a function of which implementation of 802.11 is being used.
#
# So again, a, b, g, n, and ac, all have different specifications when it comes to the speed and distance. So it always depends on which one you are using. And final, channel bonding is the process of quite simply combining two or more channels to increase overall bandwidth. Now it depends on your configuration, with respect to how this is implemented. But, at the end of the day, it really is just that combination of channels for increased bandwidth. So, hopefully you made out okay with those questions and, if so, we are ready to move on to our next course.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="wirelessTechnologiesTest"></a>
# ***
# ### ⚡ Test
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %% [markdown]
# # END JUPYTER NOTEBOOK
